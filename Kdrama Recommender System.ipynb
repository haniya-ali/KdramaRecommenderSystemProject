# %% [markdown]
# #                                        Kdrama Recommender System 🤩

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Introduction

# %%
import pandas as pd

# %% [markdown]
# ## Dataset

# %%
kdrama_data = pd.read_csv('/Users/haniyaali/Downloads/kdrama_list.csv')
kdrama_data
# Out:
#       Unnamed: 0                         Name  Year  \
# 0              0               Move to Heaven  2021
# 1              1            Weak Hero Class 1  2022
# 2              2   Hospital Playlist Season 2  2021
# 3              3               Flower of Evil  2020
# 4              4            Hospital Playlist  2020
# ...          ...                          ...   ...
# 1642        1642       The Facetale: Cinderia  2016
# 1643        1643                 Coffee House  2010
# 1644        1644    Love Detective Sherlock K  2015
# 1645        1645          A Beauty of Revenge  2021
# 1646        1646  Immutable Law of First Love  2015
#
#                                     Genre  \
# 0                             Life, Drama
# 1                    Action, Youth, Drama
# 2           Romance, Life, Drama, Medical
# 3     Thriller, Romance, Crime, Melodrama
# 4           Romance, Life, Drama, Medical
# ...                                   ...
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# # Modeling

# %% [markdown]
# # Analysis

# %% [markdown]
# # Conclusion
